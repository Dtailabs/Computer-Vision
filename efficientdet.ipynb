# %%
# !git clone https://github.com/signatrix/efficientdet.git
# Out:
# Cloning into 'efficientdet'...
# remote: Enumerating objects: 144, done.
# remote: Counting objects: 100% (144/144), done.
# remote: Compressing objects: 100% (107/107), done.
# remote: Total 144 (delta 67), reused 104 (delta 34), pack-reused 0
# Receiving objects: 100% (144/144), 28.03 MiB | 8.54 MiB/s, done.
# Resolving deltas: 100% (67/67), done.

# %%
# %cd efficientdet/
# Out:
# /content/efficientdet

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 204kB 14.5MB/s
# ...
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.5.1-cp36-none-any.whl size=11768 sha256=d81b07f98ce770a21a49e2ae487c7e4b51f605cca396d1684c5a03ebf623334a
#   Stored in directory: /root/.cache/pip/wheels/52/0c/8e/58d91f29f0f8cbb45231a145312939a5423dc82c61cc731361
# Successfully built efficientnet-pytorch
# ...

# %%
# !wget http://images.cocodataset.org/zips/val2017.zip
# !unzip ./val2017.zip
# !wget http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# !unzip ./annotations_trainval2017.zip
# Out:
# --2020-01-07 03:56:09--  http://images.cocodataset.org/zips/val2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.216.110.171
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.216.110.171|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 815585330 (778M) [application/zip]
# Saving to: ‘val2017.zip’
#
# val2017.zip         100%[===================>] 777.80M  13.6MB/s    in 58s
#
# 2020-01-07 03:57:07 (13.4 MB/s) - ‘val2017.zip’ saved [815585330/815585330]
#
# Archive:  ./val2017.zip
#    creating: val2017/
#  extracting: val2017/000000212226.jpg
#  extracting: val2017/000000231527.jpg
#  extracting: val2017/000000578922.jpg
#  extracting: val2017/000000062808.jpg
#  extracting: val2017/000000119038.jpg
#  extracting: val2017/000000114871.jpg
#  extracting: val2017/000000463918.jpg
#  extracting: val2017/000000365745.jpg
#  extracting: val2017/000000320425.jpg
#  extracting: val2017/000000481404.jpg
# ...

# %%
# !mkdir -p data/COCO/images

# %%
# !mv val2017/ data/COCO/images
# !mv annotations/ data/COCO

# %%
# %ls data/COCO
# Out:
# annotations/  images/

# %%
# !python test_dataset.py
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:493: SourceChangeWarning: source code of class 'src.model.EfficientDet' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:493: SourceChangeWarning: source code of class 'src.loss.FocalLoss' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# loading annotations into memory...
# Done (t=0.48s)
# creating index...
# index created!

# %%
# %ls predictions/
# Out:
# 000000000139_prediction.jpg  000000289659_prediction.jpg
# 000000000285_prediction.jpg  000000289702_prediction.jpg
# 000000000632_prediction.jpg  000000289741_prediction.jpg
# 000000000724_prediction.jpg  000000289938_prediction.jpg
# 000000000776_prediction.jpg  000000289960_prediction.jpg
# 000000000785_prediction.jpg  000000289992_prediction.jpg
# 000000000802_prediction.jpg  000000290081_prediction.jpg
# 000000000872_prediction.jpg  000000290163_prediction.jpg
# 000000000885_prediction.jpg  000000290179_prediction.jpg
# 000000001000_prediction.jpg  000000290248_prediction.jpg
# 000000001268_prediction.jpg  000000290293_prediction.jpg
# 000000001296_prediction.jpg  000000290592_prediction.jpg
# 000000001353_prediction.jpg  000000290619_prediction.jpg
# 000000001425_prediction.jpg  000000290768_prediction.jpg
# 000000001490_prediction.jpg  000000290771_prediction.jpg
# 000000001503_prediction.jpg  000000290833_prediction.jpg
# ...

# %%
from IPython.display import Image,display_jpeg

# %%
from pathlib import Path
image_path = Path("predictions/")

# %%
for idx, img_path in enumerate(image_path.glob("*.jpg")):
    display_jpeg(Image(str(img_path)))
    if idx == 100:
        break
